# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

# %% [markdown]
# # Read dataset

# %% [markdown]
# Since, there can only be 36 runs at max in 1 over, the score exceeding 36 is anomaly.

# %%
df = pd.read_csv('cricket.csv')
df
# Out:
#     Overs  Scores
# 0       1      15
# 1       2      10
# 2       3      17
# 3       4      10
# 4       5      12
# 5       6      20
# 6       7     100
# 7       8       7
# 8       9       8
# 9      10      11
# 10     11     100
# 11     12      14
# 12     13       3
# 13     14     100
# 14     15      11
# 15     16      13
# 16     17     100
# 17     18      16
# 18     19      26
# 19     20      30

# %% [markdown]
# # Model Training

# %%
model = IsolationForest(n_estimators=100, max_samples = 'auto', contamination = float(0.2), max_features=1.0)
model.fit(df[['Scores']])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.2)

# %% [markdown]
# # Predictions

# %%
df['anomalies_scores'] = model.decision_function(df[['Scores']])
x=df['anomalies_scores']
df['anomaly'] =model.predict(df[['Scores']])
y=df['anomaly']
df.head(20)
# Out:
#     Overs  Scores  anomalies_scores  anomaly
# 0       1      15          0.224707        1
# 1       2      10          0.239214        1
# 2       3      17          0.192333        1
# 3       4      10          0.239214        1
# 4       5      12          0.233195        1
# 5       6      20          0.121763        1
# 6       7     100         -0.016525       -1
# 7       8       7          0.169324        1
# 8       9       8          0.201293        1
# 9      10      11          0.246851        1
# 10     11     100         -0.016525       -1
# 11     12      14          0.227266        1
# 12     13       3          0.004131        1
# 13     14     100         -0.016525       -1
# 14     15      11          0.246851        1
# 15     16      13          0.225680        1
# 16     17     100         -0.016525       -1
# 17     18      16          0.212670        1
# 18     19      26          0.071466        1
# 19     20      30          0.020478        1

# %%
plt.scatter(y,df['Overs'], marker='x')

plt.title('Anomalies in Overs')
plt.xlabel('Anomaly')
plt.ylabel('Overs')

plt.axis([-2,2,0,25])
# Out:
# (-2.0, 2.0, 0.0, 25.0)
