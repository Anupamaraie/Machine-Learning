# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# mnist = tf.keras.datasets.mnist

# %%
# (x_train,y_train), (x_test, y_test) = mnist.load_data()

# %%
# x_train = tf.keras.utils.normalize(x_train, axis=1)
# x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Flatten(input_shape=(28,28)))

# %%
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2717 - accuracy: 0.9186
# Epoch 2/3
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1093 - accuracy: 0.9665
# Epoch 3/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0733 - accuracy: 0.9776

# %%
# model.save('handwritten.model')
# Out:
# INFO:tensorflow:Assets written to: handwritten.model\assets

# %%
model = tf.keras.models.load_model('handwritten.model')
loss, accuracy = model.evaluate(x_test, y_test)

print(loss)
print(accuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1014 - accuracy: 0.9685
# 0.1013653576374054
# 0.968500018119812

# %%
image_number = 1
while os.path.isfile(f"images/digit{image_number}.png"):
    try:
        img = cv2.imread(f"images/digit{image_number}.png")[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print(f"The digit is probably a {np.argmax(prediction)}")
        plt.imshow(img[0], cmap=plt.cm.binary)
        plt.show()
    except:
        print("Error!! :(")
        
    finally:
        image_number += 1
# Out:
# 1/1 [==============================] - 0s 88ms/step
# The digit is probably a 8
# 1/1 [==============================] - 0s 33ms/step
# The digit is probably a 2
# 1/1 [==============================] - 0s 30ms/step
# The digit is probably a 6
# 1/1 [==============================] - 0s 30ms/step
# The digit is probably a 2
# 1/1 [==============================] - 0s 33ms/step
# The digit is probably a 5
# 1/1 [==============================] - 0s 33ms/step
# The digit is probably a 3
